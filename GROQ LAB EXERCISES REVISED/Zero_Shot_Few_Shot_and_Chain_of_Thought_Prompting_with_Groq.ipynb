# %%
# %pip install groq python-dotenv
# Out:
# Requirement already satisfied: groq in /Users/mannasethsotsky/anaconda3/lib/python3.12/site-packages (1.0.0)
# Requirement already satisfied: python-dotenv in /Users/mannasethsotsky/anaconda3/lib/python3.12/site-packages (0.21.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in /Users/mannasethsotsky/anaconda3/lib/python3.12/site-packages (from groq) (4.2.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /Users/mannasethsotsky/anaconda3/lib/python3.12/site-packages (from groq) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /Users/mannasethsotsky/anaconda3/lib/python3.12/site-packages (from groq) (0.27.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /Users/mannasethsotsky/anaconda3/lib/python3.12/site-packages (from groq) (2.8.2)
# Requirement already satisfied: sniffio in /Users/mannasethsotsky/anaconda3/lib/python3.12/site-packages (from groq) (1.3.0)
# Requirement already satisfied: typing-extensions<5,>=4.10 in /Users/mannasethsotsky/anaconda3/lib/python3.12/site-packages (from groq) (4.15.0)
# Requirement already satisfied: idna>=2.8 in /Users/mannasethsotsky/anaconda3/lib/python3.12/site-packages (from anyio<5,>=3.5.0->groq) (3.7)
# Requirement already satisfied: certifi in /Users/mannasethsotsky/anaconda3/lib/python3.12/site-packages (from httpx<1,>=0.23.0->groq) (2024.8.30)
# Requirement already satisfied: httpcore==1.* in /Users/mannasethsotsky/anaconda3/lib/python3.12/site-packages (from httpx<1,>=0.23.0->groq) (1.0.2)
# Requirement already satisfied: h11<0.15,>=0.13 in /Users/mannasethsotsky/anaconda3/lib/python3.12/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->groq) (0.14.0)
# Requirement already satisfied: annotated-types>=0.4.0 in /Users/mannasethsotsky/anaconda3/lib/python3.12/site-packages (from pydantic<3,>=1.9.0->groq) (0.6.0)
# Requirement already satisfied: pydantic-core==2.20.1 in /Users/mannasethsotsky/anaconda3/lib/python3.12/site-packages (from pydantic<3,>=1.9.0->groq) (2.20.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
import json
from dotenv import load_dotenv
from groq import Groq
import os

# %%
# Initialize Groq client
load_dotenv()
client = Groq(api_key=os.getenv("GROQ_API_KEY"))
model = "llama-3.3-70b-versatile"

# %%
def query_groq(prompt, model=model, temperature=0.7):
    response = client.chat.completions.create(
        model=model,
        messages=[
            {"role": "user", "content": prompt}
        ],
        temperature=temperature,
        max_tokens=150  # Adjust as necessary
    )
    return response.choices[0].message.content.strip()

# %%
# Zero-Shot Prompting
zero_shot_prompt = "What are the benefits of regular exercise?"
zero_shot_response = query_groq(zero_shot_prompt)

print("Zero-Shot Response:")
print(zero_shot_response)
# Out:
# Zero-Shot Response:
# Regular exercise provides numerous benefits for the body, mind, and overall well-being. Some of the key advantages of regular physical activity include:
#
# 1. **Weight Management**: Exercise helps burn calories, maintain weight loss, and reduce the risk of obesity-related diseases.
# 2. **Improved Cardiovascular Health**: Regular physical activity strengthens the heart, lowers blood pressure, and reduces the risk of heart disease, stroke, and high blood pressure.
# 3. **Increased Strength and Flexibility**: Exercise, especially resistance training, helps build muscle mass, improve bone density, and enhance flexibility.
# 4. **Enhanced Mental Health**: Physical activity reduces stress, anxiety, and depression by releasing endorphins, also known as "feel-good" hormones.
# 5. **Better Sleep

# %%
# Few-Shot Prompting
few_shot_prompt = (
    "Translate 'What is your name' to French, following the format in these examples:\n"
    "1. Hello. -> Bonjour.\n"
    "2. How are you? -> Comment ça va?\n"
)
few_shot_response = query_groq(few_shot_prompt)

print("\nFew-Shot Response:")
print(few_shot_response)
# Out:
# Few-Shot Response:
# What is your name? -> Quel est votre nom?

# %%
# Chain-of-Thought Prompting
cot_prompt = (
    "Calculate the following: If I have 3 apples and I buy 2 more, "
    "how many apples do I have in total? Please show your work."
)
cot_response = query_groq(cot_prompt)

print("\nChain-of-Thought Response:")
print(cot_response)
# Out:
# Chain-of-Thought Response:
# To calculate the total number of apples, I will add the initial number of apples to the number of apples purchased.
#
# Initial number of apples: 3
# Number of apples purchased: 2
#
# Total number of apples = Initial number of apples + Number of apples purchased
# = 3 + 2
# = 5
#
# Therefore, you have a total of 5 apples.

# %%
# Chain-of-Thought Prompting
notcot_prompt = (
    "If I have 3 apples and I buy 2 more, "
    "how many apples do I have in total?"
)
cot_response = query_groq(cot_prompt)

print("\nChain-of-Thought Response:")
print(cot_response)
# Out:
# Chain-of-Thought Response:
# To find the total number of apples, we need to add the number of apples you already have to the number of apples you bought. Here's the calculation:
#
# Initial number of apples = 3
# Number of apples bought = 2
#
# Total number of apples = Initial number of apples + Number of apples bought
# = 3 + 2
# = 5
#
# Therefore, you have 5 apples in total.
